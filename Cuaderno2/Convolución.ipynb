# %% [markdown]
# <a href="https://colab.research.google.com/github/Ferchisx/EjerciciosSyS/blob/Ejercicios/Cuaderno2/Convoluci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CONVOLUCION: Se dejaron tres integrales por resolver respecto a la convolución de 2 señales:

# %% [markdown]
# ![WhatsApp Image 2023-09-29 at 22.00.49.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Todas estas respuestas se basan en que la señal h(t) realiza un recorrido por el eje X (del tiempo) haciendo un traslape con la señal estática x(t).
# De aquí a que den lugar 3 secciones de ejercicio con 2 integrales de diferentes límites.
