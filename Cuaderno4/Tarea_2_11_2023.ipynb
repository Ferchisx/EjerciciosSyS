# %% [markdown]
# <a href="https://colab.research.google.com/github/Ferchisx/EjerciciosSyS/blob/Ejercicios/Cuaderno4/Tarea_2_11_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CUADERNILLO 1: DEFINICIÓN
# ![WhatsApp Image 2023-11-02 at 14.24.26_1abb191f.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# CUADERNILLO 2: PROPIEDADES

# %%
# %matplotlib inline
import sympy as sym
sym.init_printing()
#se definen las variables simbólicas y se aplica la función de laplace de sympy
t, w0 = sym.symbols('t omega0', real=True)
s = sym.symbols('s', complex=True)

x = sym.sin(w0*t)
X, a, cond = sym.laplace_transform(x, t, s)
X, a, cond
# Out:
# ⎛   ω₀            ⎞
# ⎜────────, 0, True⎟
# ⎜  2    2         ⎟
# ⎝ω₀  + s          ⎠

# %% [markdown]
# ![WhatsApp Image 2023-11-02 at 15.18.00_7610923a.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# CUADERNILLO 3: TEORÍA

# %% [markdown]
# CUADERNILLO 4: TRANSFORMADA INVERSA

# %% [markdown]
# ![WhatsApp Image 2023-11-02 at 16.47.08_9b4a53a2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-11-02 at 16.47.08_3152642a.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-11-02 at 16.47.08_0797bdfb.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# NOTA: No logro comprender como la resolución del sistema de ecuaciones arroja esa respuesta y en el código daba otra cosa. Porque cuando comparé respuestas con unos compañeros, prácticamente tenían un machetazo que no comprendo.

# %%
# @title Comprobación en código

# %matplotlib inline
import sympy as sym
sym.init_printing()

# s = sym.symbols('s', complex=True)
t = sym.symbols('t', real=True)

Y = 1/((s+1)*((s+2)**2))
Y
# Out:
#        1
# ────────────────
#                2
# (s + 1)⋅(s + 2)

# %%
xt = sym.inverse_laplace_transform(Xp, s, t)
xt
# Out:
#      -2⋅t         -t         -2⋅t
# - t⋅ℯ    ⋅θ(t) + ℯ  ⋅θ(t) - ℯ    ⋅θ(t)
